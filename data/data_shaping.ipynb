# %%
import pandas as pd

# %%
data = pd.read_csv('sahko_data.csv')
data.head()
# Out:
#     price            startDate                 time  temp  wind  hour  \
# 0  14.045  2026-02-01 22:00:00  2026-02-01 22:00:00 -23.2   9.0    22
# 1  15.592  2026-02-01 21:00:00  2026-02-01 21:00:00 -23.1   8.3    21
# 2  16.787  2026-02-01 20:00:00  2026-02-01 20:00:00 -22.9   8.3    20
# 3  15.878  2026-02-01 19:00:00  2026-02-01 19:00:00 -22.6   8.3    19
# 4  16.314  2026-02-01 18:00:00  2026-02-01 18:00:00 -22.2   7.9    18
#
#    dayofweek  month
# 0          6      2
# 1          6      2
# 2          6      2
# 3          6      2
# 4          6      2
